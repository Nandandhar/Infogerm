# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
data = pd.read_csv(r"D:\NANDAN's Documents\Infogerm int\Coffee sales.csv")
data
# Out:
#             date datetime cash_type                 card  money    coffee_name
# 0     01-03-2024  15:50.5      card  ANON-0000-0000-0001  38.70          Latte
# 1     01-03-2024  19:22.5      card  ANON-0000-0000-0002  38.70  Hot Chocolate
# 2     01-03-2024  20:18.1      card  ANON-0000-0000-0002  38.70  Hot Chocolate
# 3     01-03-2024  46:33.0      card  ANON-0000-0000-0003  28.90      Americano
# 4     01-03-2024  48:14.6      card  ANON-0000-0000-0004  38.70          Latte
# ...          ...      ...       ...                  ...    ...            ...
# 1912  13-10-2024  34:25.9      card  ANON-0000-0000-0650  25.96        Cortado
# 1913  13-10-2024  53:20.7      card  ANON-0000-0000-0507  35.76          Latte
# 1914  13-10-2024  54:22.4      card  ANON-0000-0000-0507  35.76          Latte
# 1915  13-10-2024  22:58.8      card  ANON-0000-0000-0753  35.76     Cappuccino
# 1916  13-10-2024  43:04.9      card  ANON-0000-0000-0257  35.76     Cappuccino
#
# [1917 rows x 6 columns]

# %%
data.shape
# Out:
# (1917, 6)

# %%
data.describe()
# Out:
#              money
# count  1917.000000
# mean     31.560584
# std       5.260794
# min      18.120000
# 25%      27.920000
# 50%      32.820000
# 75%      35.760000
# max      40.000000

# %%
data.isnull().sum()
# Out:
# date            0
# datetime        0
# cash_type       0
# card           89
# money           0
# coffee_name     0
# dtype: int64

# %%
coffee_brown = '#6F4E37'

# %%
data['datetime'] = pd.to_datetime(data['datetime'])

daily_sales = data.groupby(data['datetime'].dt.date)['money'].sum()

plt.figure(figsize=(10, 6))
plt.plot(daily_sales.index, daily_sales.values, marker='o', linestyle='-', color=coffee_brown)
plt.title('Daily Coffee Sales')
plt.xlabel('Date')
plt.ylabel('Total Sales (Money)')
plt.xticks(rotation=45)
plt.grid(True)
plt.tight_layout()
plt.show()
# Out:
# C:\Users\hP\AppData\Local\Temp\ipykernel_1660\3449125334.py:1: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   data['datetime'] = pd.to_datetime(data['datetime'])
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# File parsing.pyx:684, in pandas._libs.tslibs.parsing.dateutil_parse()
#
# ValueError: hour must be in 0..23
#
# The above exception was the direct cause of the following exception:
#
# DateParseError                            Traceback (most recent call last)
# Cell In[73], line 1
# ----> 1 data['datetime'] = pd.to_datetime(data['datetime'])
#       3 daily_sales = data.groupby(data['datetime'].dt.date)['money'].sum()
#       5 plt.figure(figsize=(10, 6))
#
# ...

# %%
coffee_popularity = data['coffee_name'].value_counts()

plt.figure(figsize=(10, 6))
coffee_popularity.plot(kind='bar', color=coffee_brown)
plt.title('Most Popular Coffee Types')
plt.xlabel('Coffee Type')
plt.ylabel('Number of Purchases')
plt.xticks(rotation=45)
plt.grid(True)
plt.tight_layout()
plt.show()

# %%
sales_by_coffee_type = data.groupby('coffee_name')['money'].sum()

plt.figure(figsize=(10, 6))
sales_by_coffee_type.plot(kind='bar', color=coffee_brown)
plt.title('Total Sales by Coffee Type')
plt.xlabel('Coffee Type')
plt.ylabel('Total Sales (Money)')
plt.xticks(rotation=45)
plt.grid(True)
plt.tight_layout()
plt.show()

# %%
hourly_sales = data.groupby(data['datetime'].dt.hour)['money'].sum()

plt.figure(figsize=(10, 6))
hourly_sales.plot(kind='line', marker='o', linestyle='-', color=coffee_brown)
plt.title('Hourly Coffee Sales')
plt.xlabel('Hour of the Day')
plt.ylabel('Total Sales (Money)')
plt.grid(True)
plt.tight_layout()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[34], line 1
# ----> 1 hourly_sales = data.groupby(data['datetime'].dt.hour)['money'].sum()
#       3 plt.figure(figsize=(10, 6))
#       4 hourly_sales.plot(kind='line', marker='o', linestyle='-', color=coffee_brown)
#
# File ~\anaconda3\Lib\site-packages\pandas\core\generic.py:6299, in NDFrame.__getattr__(self, name)
#    6292 if (
#    6293     name not in self._internal_names_set
#    6294     and name not in self._metadata
#    6295     and name not in self._accessors
#    6296     and self._info_axis._can_hold_identifiers_and_holds_name(name)
#    6297 ):
#    6298     return self[name]
# -> 6299 return object.__getattribute__(self, name)
#
# File ~\anaconda3\Lib\site-packages\pandas\core\accessor.py:224, in CachedAccessor.__get__(self, obj, cls)
#     221 if obj is None:
# ...

# %%
payment_distribution = data['cash_type'].value_counts()

plt.figure(figsize=(10, 6))
payment_distribution.plot(kind='bar', color=coffee_brown)
plt.title('Payment Method Distribution')
plt.xlabel('Payment Method')
plt.ylabel('Number of Transactions')
plt.xticks(rotation=0)
plt.grid(True)
plt.tight_layout()
plt.show()
